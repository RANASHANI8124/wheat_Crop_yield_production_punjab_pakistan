# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/home/asad-shareef/Personel/Nothing/final_THP.csv")
df=df.sort_values(by=["district","crop"])
df=df[df["crop"]=="wheat"]
df["flag"]=df["kg/acre"]==0
df
# Out:
#      district  year   crop  germ_temp  veg_temp  flow_temp  fruit_temp  \
# 1      attock  1981  wheat      19.43     13.58      11.05       13.90
# 4      attock  1982  wheat      18.05     13.87      11.85       10.37
# 7      attock  1983  wheat      18.19     11.68      10.73       13.05
# 10     attock  1984  wheat      18.36     13.30      10.95       10.79
# 13     attock  1985  wheat      17.59     11.72      10.76       15.50
# ...       ...   ...    ...        ...       ...        ...         ...
# 3682   vehari  2020  wheat      20.28     14.28      11.84       16.89
# 3685   vehari  2021  wheat      19.27     13.87      12.52       17.85
# 3688   vehari  2022  wheat      21.42     15.43      13.51       16.82
# 3691   vehari  2023  wheat      22.11     17.27      12.51       20.28
# 3694   vehari  2024  wheat      21.54     16.55      14.24       16.64
#
#       germ_rh  veg_rh  flow_rh  fruit_rh  germ_prec  veg_prec  flow_prec  \
# 1       54.34   63.23    56.60     55.31      14.34     34.45      92.56
# 4       29.82   35.65    43.78     60.83      10.91      8.13      23.17
# 7       38.99   53.58    49.26     50.46      55.39     40.42      37.51
# 10      22.70   33.30    32.85     45.32       1.61      1.68       4.15
# 13      32.51   37.92    48.24     26.25       9.70     13.73       5.94
# ...       ...     ...      ...       ...        ...       ...        ...
# 3682    49.43   40.85    58.93     45.56      14.94      9.01      32.43
# 3685    38.57   58.52    53.35     46.25     420.29      7.88      13.96
# 3688    25.76   30.07    57.59     45.90       0.00      0.48      42.10
# 3691    36.05   31.71    33.33     28.21       3.68      1.14       2.60
# 3694    44.09   36.21    37.54     33.34       1.46      0.00       0.41
#
#       fruit_prec   n__g/kg  soc__g/kg  soil_ph      kg/acre   flag
# 1          58.41  1.538567   16.76787  7.54444   331.578947  False
# 4         222.06  1.538567   16.76787  7.54444   402.024291  False
# 7          28.24  1.538567   16.76787  7.54444   351.821862  False
# 10         40.01  1.538567   16.76787  7.54444   373.684211  False
# 13          7.03  1.538567   16.76787  7.54444   535.627530  False
# ...          ...       ...        ...      ...          ...    ...
# 3682        3.45  1.546484    9.56018  7.59187  1412.145749  False
# 3685        0.03  1.546484    9.56018  7.59187  1410.931174  False
# 3688        0.87  1.546484    9.56018  7.59187  1505.263158  False
# 3691        0.85  1.546484    9.56018  7.59187  1628.340081  False
# 3694        4.70  1.546484    9.56018  7.59187  1497.975709  False
#
# [1540 rows x 20 columns]

# %%
low=df["kg/acre"].quantile(0.01)
high=df["kg/acre"].quantile(0.99)
df=df[(df["kg/acre"]>=low)&(df["kg/acre"]<=high)]

# %%
df["soil"]=df["n__g/kg"]+df["soc__g/kg"]
df["total_prec"]=df["germ_prec"]+df["veg_prec"]+df["flow_prec"]+df["fruit_prec"]
df["avg_rh"]=(df["germ_rh"]+df["veg_rh"]+df["flow_rh"]+df["fruit_rh"])/4

# %%
df.columns
# Out:
# Index(['district', 'year', 'crop', 'germ_temp', 'veg_temp', 'flow_temp',
#        'fruit_temp', 'germ_rh', 'veg_rh', 'flow_rh', 'fruit_rh', 'germ_prec',
#        'veg_prec', 'flow_prec', 'fruit_prec', 'n__g/kg', 'soc__g/kg',
#        'soil_ph', 'kg/acre', 'flag', 'soil', 'total_prec', 'avg_rh'],
#       dtype='str')

# %%
dfc=df.drop(["district","crop"],axis=1)

# %%
dfc.corr()
# Out:
#                 year  germ_temp  veg_temp  flow_temp  fruit_temp   germ_rh  \
# year        1.000000  -0.089605 -0.000740  -0.123608    0.137838  0.379004
# germ_temp  -0.089605   1.000000  0.707915   0.618146    0.342640 -0.564470
# veg_temp   -0.000740   0.707915  1.000000   0.635207    0.408502 -0.577842
# flow_temp  -0.123608   0.618146  0.635207   1.000000    0.565888 -0.459353
# fruit_temp  0.137838   0.342640  0.408502   0.565888    1.000000 -0.186901
# germ_rh     0.379004  -0.564470 -0.577842  -0.459353   -0.186901  1.000000
# veg_rh      0.023734  -0.520558 -0.579085  -0.412863   -0.182948  0.735882
# flow_rh     0.176656  -0.439369 -0.343904  -0.549962   -0.253418  0.505618
# fruit_rh    0.179114  -0.415971 -0.395501  -0.474168   -0.562260  0.472035
# germ_prec   0.164545  -0.298400 -0.266259  -0.178570    0.035537  0.344468
# veg_prec   -0.144691  -0.328480 -0.403466  -0.320026   -0.241745  0.321351
# flow_prec   0.167395  -0.332119 -0.167179  -0.401791   -0.295571  0.324956
# fruit_prec  0.008005  -0.352212 -0.344853  -0.309861   -0.387842  0.318169
# n__g/kg     0.003545  -0.409518 -0.277653  -0.325680   -0.329244  0.193511
# soc__g/kg   0.007454  -0.590310 -0.421598  -0.492938   -0.470564  0.296144
# soil_ph    -0.003525   0.257039  0.158306   0.187834    0.189767 -0.144800
# kg/acre     0.637893   0.267033  0.256427   0.188936    0.365872  0.076066
# flag       -0.244602  -0.035426 -0.070385  -0.018312   -0.066115  0.020661
# soil        0.007200  -0.581043 -0.413729  -0.483826   -0.463414  0.290488
# total_prec  0.092201  -0.513439 -0.457829  -0.463785   -0.369401  0.507727
# avg_rh      0.232554  -0.597445 -0.587458  -0.578898   -0.365154  0.839630
#
#               veg_rh   flow_rh  fruit_rh  germ_prec  ...  flow_prec  \
# year        0.023734  0.176656  0.179114   0.164545  ...   0.167395
# germ_temp  -0.520558 -0.439369 -0.415971  -0.298400  ...  -0.332119
# veg_temp   -0.579085 -0.343904 -0.395501  -0.266259  ...  -0.167179
# flow_temp  -0.412863 -0.549962 -0.474168  -0.178570  ...  -0.401791
# fruit_temp -0.182948 -0.253418 -0.562260   0.035537  ...  -0.295571
# germ_rh     0.735882  0.505618  0.472035   0.344468  ...   0.324956
# veg_rh      1.000000  0.539420  0.474687   0.382074  ...   0.250867
# flow_rh     0.539420  1.000000  0.571071   0.247948  ...   0.718569
# fruit_rh    0.474687  0.571071  1.000000   0.133605  ...   0.519583
# germ_prec   0.382074  0.247948  0.133605   1.000000  ...   0.095817
# veg_prec    0.606482  0.397786  0.382523   0.114264  ...   0.231210
# flow_prec   0.250867  0.718569  0.519583   0.095817  ...   1.000000
# fruit_prec  0.310268  0.255769  0.592801   0.109813  ...   0.266152
# n__g/kg     0.156864  0.238859  0.293896   0.097496  ...   0.303911
# soc__g/kg   0.249404  0.377895  0.447035   0.110216  ...   0.418141
# soil_ph    -0.108864 -0.169309 -0.195490  -0.047615  ...  -0.219975
# kg/acre    -0.149349 -0.045216 -0.117490   0.053518  ...  -0.082450
# flag        0.104838  0.065878  0.028680  -0.001668  ...   0.025995
# soil        0.244126  0.369997  0.438648   0.110261  ...   0.412744
# total_prec  0.560739  0.587279  0.664919   0.516855  ...   0.590288
# avg_rh      0.851031  0.789243  0.774537   0.341628  ...   0.545799
#
#             fruit_prec   n__g/kg  soc__g/kg   soil_ph   kg/acre      flag  \
# year          0.008005  0.003545   0.007454 -0.003525  0.637893 -0.244602
# germ_temp    -0.352212 -0.409518  -0.590310  0.257039  0.267033 -0.035426
# veg_temp     -0.344853 -0.277653  -0.421598  0.158306  0.256427 -0.070385
# flow_temp    -0.309861 -0.325680  -0.492938  0.187834  0.188936 -0.018312
# fruit_temp   -0.387842 -0.329244  -0.470564  0.189767  0.365872 -0.066115
# germ_rh       0.318169  0.193511   0.296144 -0.144800  0.076066  0.020661
# veg_rh        0.310268  0.156864   0.249404 -0.108864 -0.149349  0.104838
# flow_rh       0.255769  0.238859   0.377895 -0.169309 -0.045216  0.065878
# fruit_rh      0.592801  0.293896   0.447035 -0.195490 -0.117490  0.028680
# germ_prec     0.109813  0.097496   0.110216 -0.047615  0.053518 -0.001668
# veg_prec      0.346339  0.262830   0.337031 -0.158961 -0.300413  0.091846
# flow_prec     0.266152  0.303911   0.418141 -0.219975 -0.082450  0.025995
# fruit_prec    1.000000  0.319784   0.421857 -0.201303 -0.246273  0.032566
# n__g/kg       0.319784  1.000000   0.869463 -0.523072 -0.247209 -0.009498
# soc__g/kg     0.421857  0.869463   1.000000 -0.470190 -0.333282  0.015140
# soil_ph      -0.201303 -0.523072  -0.470190  1.000000  0.077458  0.107406
# kg/acre      -0.246273 -0.247209  -0.333282  0.077458  1.000000 -0.569408
# flag          0.032566 -0.009498   0.015140  0.107406 -0.569408  1.000000
# soil          0.417523  0.889300   0.999131 -0.479423 -0.329401  0.013214
# total_prec    0.794964  0.390319   0.511269 -0.248590 -0.221400  0.049064
# avg_rh        0.457532  0.270130   0.418946 -0.189087 -0.073401  0.067343
#
#                 soil  total_prec    avg_rh
# year        0.007200    0.092201  0.232554
# germ_temp  -0.581043   -0.513439 -0.597445
# veg_temp   -0.413729   -0.457829 -0.587458
# flow_temp  -0.483826   -0.463785 -0.578898
# fruit_temp -0.463414   -0.369401 -0.365154
# germ_rh     0.290488    0.507727  0.839630
# veg_rh      0.244126    0.560739  0.851031
# flow_rh     0.369997    0.587279  0.789243
# fruit_rh    0.438648    0.664919  0.774537
# germ_prec   0.110261    0.516855  0.341628
# veg_prec    0.334189    0.563706  0.526204
# flow_prec   0.412744    0.590288  0.545799
# fruit_prec  0.417523    0.794964  0.457532
# n__g/kg     0.889300    0.390319  0.270130
# soc__g/kg   0.999131    0.511269  0.418946
# soil_ph    -0.479423   -0.248590 -0.189087
# kg/acre    -0.329401   -0.221400 -0.073401
# flag        0.013214    0.049064  0.067343
# soil        1.000000    0.506250  0.410639
# total_prec  0.506250    1.000000  0.711994
# avg_rh      0.410639    0.711994  1.000000
#
# [21 rows x 21 columns]

# %%
df=df.drop([ 'germ_rh', 'veg_rh', 'flow_rh', 'fruit_rh', 'n__g/kg', 'soc__g/kg','avg_rh'],axis=1)

# %%
plt.scatter(df["total_prec"],df["kg/acre"])

# %%
df["water_stress"]=df["total_prec"]>500

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1524 entries, 1 to 3694
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   district      1524 non-null   str
#  1   year          1524 non-null   int64
#  2   crop          1524 non-null   str
#  3   germ_temp     1524 non-null   float64
#  4   veg_temp      1524 non-null   float64
#  5   flow_temp     1524 non-null   float64
#  6   fruit_temp    1524 non-null   float64
#  7   germ_prec     1524 non-null   float64
#  8   veg_prec      1524 non-null   float64
#  9   flow_prec     1524 non-null   float64
#  10  fruit_prec    1524 non-null   float64
#  11  soil_ph       1524 non-null   float64
#  12  kg/acre       1524 non-null   float64
#  13  flag          1524 non-null   bool
#  14  soil          1524 non-null   float64
#  15  total_prec    1524 non-null   float64
#  16  water_stress  1524 non-null   bool
# dtypes: bool(2), float64(12), int64(1), str(2)
# memory usage: 193.5 KB

# %%
df.describe()
# Out:
#               year    germ_temp     veg_temp    flow_temp   fruit_temp  \
# count  1524.000000  1524.000000  1524.000000  1524.000000  1524.000000
# mean   2002.313648    20.130269    14.959449    12.940538    15.872192
# std      12.621155     1.490708     1.484399     1.416451     1.943749
# min    1981.000000    14.810000    10.700000     8.620000     9.800000
# 25%    1991.000000    19.190000    13.920000    11.977500    14.550000
# 50%    2002.000000    20.135000    14.920000    12.900000    15.960000
# 75%    2013.000000    21.190000    15.972500    13.930000    17.120000
# max    2024.000000    25.030000    20.200000    17.790000    22.720000
#
#          germ_prec     veg_prec    flow_prec   fruit_prec      soil_ph  \
# count  1524.000000  1524.000000  1524.000000  1524.000000  1524.000000
# mean      9.131719    11.729259    19.117277    29.125722     7.644175
# std      28.252340    17.198820    24.689209    41.493661     0.333901
# min       0.000000     0.000000     0.000000     0.000000     6.358080
# 25%       0.260000     0.437500     2.605000     5.957500     7.555000
# 50%       2.105000     4.530000    10.115000    15.460000     7.711910
# 75%       9.660000    16.767500    27.100000    36.745000     7.878000
# max     455.140000   188.720000   174.690000   576.600000     8.030080
#
#            kg/acre         soil   total_prec
# count  1524.000000  1524.000000  1524.000000
# mean    924.916425    12.276622    69.103976
# std     342.965741     4.318814    71.857158
# min       0.000000     6.985000     0.360000
# 25%     719.028340     9.138000    23.452500
# 50%     948.424041    11.541315    49.985000
# 75%    1185.020243    13.754063    87.265000
# max    1551.012146    28.791581   741.930000

# %%
df["district"].value_counts()
# Out:
# district
# attock             44
# bhakkar            44
# bhawalnagar        44
# chakwal            44
# dera ghazi khan    44
# faisalabad         44
# gujranwala         44
# gujrat             44
# jhang              44
# jhelum             44
# khushab            44
# lahore             44
# layyah             44
# mandi bahauddin    44
# mianwali           44
# muzaffargarh       44
# narowal            44
# rawalpindi         44
# sargodha           44
# sheikhupura        44
# sialkot            44
# toba tek singh     44
# bahawalpur         43
# hafizabad          43
# kasur              43
# khanewal           43
# multan             43
# nankana sahib      43
# rahim yar khan     43
# rajanpur           43
# sahiwal            43
# vehari             43
# lodhran            42
# okara              42
# pakpattan          42
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['district', 'year', 'crop', 'germ_temp', 'veg_temp', 'flow_temp',
#        'fruit_temp', 'germ_prec', 'veg_prec', 'flow_prec', 'fruit_prec',
#        'soil_ph', 'kg/acre', 'flag', 'soil', 'total_prec', 'water_stress'],
#       dtype='str')

# %%
cat_col=["district",'crop']
num_col=[ 'year','germ_temp', 'veg_temp', 'flow_temp', 'fruit_temp',
        'germ_prec', 'veg_prec',
       'flow_prec', 'fruit_prec', 'soil_ph','soil','total_prec']

# %%
df=pd.get_dummies(df,columns=cat_col)

# %%
df
# Out:
#       year  germ_temp  veg_temp  flow_temp  fruit_temp  germ_prec  veg_prec  \
# 1     1981      19.43     13.58      11.05       13.90      14.34     34.45
# 4     1982      18.05     13.87      11.85       10.37      10.91      8.13
# 7     1983      18.19     11.68      10.73       13.05      55.39     40.42
# 10    1984      18.36     13.30      10.95       10.79       1.61      1.68
# 13    1985      17.59     11.72      10.76       15.50       9.70     13.73
# ...    ...        ...       ...        ...         ...        ...       ...
# 3679  2019      21.47     15.04      12.65       14.45       0.06      7.57
# 3682  2020      20.28     14.28      11.84       16.89      14.94      9.01
# 3685  2021      19.27     13.87      12.52       17.85     420.29      7.88
# 3688  2022      21.42     15.43      13.51       16.82       0.00      0.48
# 3694  2024      21.54     16.55      14.24       16.64       1.46      0.00
#
#       flow_prec  fruit_prec  soil_ph  ...  district_rahim yar khan  \
# 1         92.56       58.41  7.54444  ...                    False
# 4         23.17      222.06  7.54444  ...                    False
# 7         37.51       28.24  7.54444  ...                    False
# 10         4.15       40.01  7.54444  ...                    False
# 13         5.94        7.03  7.54444  ...                    False
# ...         ...         ...      ...  ...                      ...
# 3679      16.90       16.34  7.59187  ...                    False
# 3682      32.43        3.45  7.59187  ...                    False
# 3685      13.96        0.03  7.59187  ...                    False
# 3688      42.10        0.87  7.59187  ...                    False
# 3694       0.41        4.70  7.59187  ...                    False
#
#       district_rajanpur  district_rawalpindi  district_sahiwal  \
# 1                 False                False             False
# 4                 False                False             False
# 7                 False                False             False
# 10                False                False             False
# 13                False                False             False
# ...                 ...                  ...               ...
# 3679              False                False             False
# 3682              False                False             False
# 3685              False                False             False
# 3688              False                False             False
# 3694              False                False             False
#
#       district_sargodha  district_sheikhupura  district_sialkot  \
# 1                 False                 False             False
# 4                 False                 False             False
# 7                 False                 False             False
# 10                False                 False             False
# 13                False                 False             False
# ...                 ...                   ...               ...
# 3679              False                 False             False
# 3682              False                 False             False
# 3685              False                 False             False
# 3688              False                 False             False
# 3694              False                 False             False
#
#       district_toba tek singh  district_vehari  crop_wheat
# 1                       False            False        True
# 4                       False            False        True
# 7                       False            False        True
# 10                      False            False        True
# 13                      False            False        True
# ...                       ...              ...         ...
# 3679                    False             True        True
# 3682                    False             True        True
# 3685                    False             True        True
# 3688                    False             True        True
# 3694                    False             True        True
#
# [1524 rows x 51 columns]

# %%
x=df.drop("kg/acre",axis=1)
y=df["kg/acre"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0,shuffle=True)

# %%
x_train
# Out:
#       year  germ_temp  veg_temp  flow_temp  fruit_temp  germ_prec  veg_prec  \
# 3853  1989      20.16     15.53      11.65       14.30       0.73     14.55
# 3820  2022      21.27     15.57      13.72       17.15       0.00      1.59
# 1741  1989      18.94     15.65      11.74       14.44       3.92     53.52
# 1249  2001      20.84     15.52      12.52       16.51       2.19     25.91
# 2551  1995      21.27     14.75      12.22       15.17       0.30     14.00
# ...    ...        ...       ...        ...         ...        ...       ...
# 3358  2000      23.08     17.53      15.09       15.50       0.01      0.00
# 808   1986      19.38     13.63      11.06       13.15       1.55     46.36
# 4216  2022      22.12     16.32      14.32       18.28       0.00      1.31
# 2743  2015      19.01     13.64      12.51       16.55       9.22      1.48
# 2593  2009      20.26     15.98      14.02       16.66       0.15     10.48
#
#       flow_prec  fruit_prec  soil_ph  ...  district_rahim yar khan  \
# 3853       6.02        1.14  7.74795  ...                    False
# 3820      27.88        0.65  7.55500  ...                    False
# 1741      33.58       15.34  7.20303  ...                    False
# 1249      22.58        0.73  7.84247  ...                    False
# 2551      42.73      116.14  6.35808  ...                    False
# ...         ...         ...      ...  ...                      ...
# 3358       8.08        2.00  7.68558  ...                    False
# 808        3.67       43.71  7.73821  ...                    False
# 4216      30.84        1.60  7.98215  ...                    False
# 2743      18.45       36.70  7.69263  ...                    False
# 2593      24.25       25.38  6.35808  ...                    False
#
#       district_rajanpur  district_rawalpindi  district_sahiwal  \
# 3853              False                False             False
# 3820              False                False             False
# 1741              False                False             False
# 1249              False                False             False
# 2551              False                False             False
# ...                 ...                  ...               ...
# 3358              False                False             False
# 808               False                False             False
# 4216               True                False             False
# 2743              False                False             False
# 2593              False                False             False
#
#       district_sargodha  district_sheikhupura  district_sialkot  \
# 3853              False                 False             False
# 3820              False                 False             False
# 1741              False                 False              True
# 1249              False                 False             False
# 2551              False                 False             False
# ...                 ...                   ...               ...
# 3358              False                 False             False
# 808               False                 False             False
# 4216              False                 False             False
# 2743              False                 False             False
# 2593              False                 False             False
#
#       district_toba tek singh  district_vehari  crop_wheat
# 3853                    False            False        True
# 3820                    False            False        True
# 1741                    False            False        True
# 1249                     True            False        True
# 2551                    False            False        True
# ...                       ...              ...         ...
# 3358                    False            False        True
# 808                     False            False        True
# 4216                    False            False        True
# 2743                    False            False        True
# 2593                    False            False        True
#
# [1219 rows x 50 columns]

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
ss=StandardScaler()
mm=MinMaxScaler()

# %%
x_train[num_col]=ss.fit_transform(x_train[num_col])
x_test[num_col]=ss.transform(x_test[num_col])

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
gbr=GradientBoostingRegressor(
    n_estimators=800,
    max_depth=10,
    learning_rate=0.01,
    subsample=0.8,
    min_weight_fraction_leaf=0.0,
    min_samples_leaf=2,
    random_state=0,
    min_samples_split=0.01
)
xgb=XGBRegressor(
    n_estimators=800,
    max_depth=10,
    learning_rate=0.01,
    subsample=0.8
)

# %%
gbr.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.01, max_depth=10, min_samples_leaf=2,
#                           min_samples_split=0.01, n_estimators=800,
#                           random_state=0, subsample=0.8)

# %%
gbr_pred=gbr.predict(x_test)

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=10,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=800,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
xgb_pred=xgb.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print("r2_gbr=",r2_score(y_test,gbr_pred))
print("r2_xgb=",r2_score(y_test,xgb_pred))
# Out:
# r2_gbr= 0.9453271203512577
# r2_xgb= 0.940155527417235

# %%
print("mae_gbr=",mean_absolute_error(y_test,gbr_pred))
print("mae_xgb=",mean_absolute_error(y_test,xgb_pred))
# Out:
# mae_gbr= 59.526894972730716
# mae_xgb= 62.44316577594188
